# %% [markdown]
# # BernoulliNB

# %%
import numpy as np

# %%
X = np.array([[0, 1, 0, 1],
              [1, 0, 1, 1],
              [0, 0, 0, 1],
              [1, 0, 1, 0]])
y = np.array([0, 1, 0, 1])

# %%
counts = {}
for label in np.unique(y):
    # iterate over each calss
    # count (sum) entries of 1 per feature
    counts[label] = X[y == label].sum(axis=0)
print("Feature counts:\n{}".format(counts))
# Out:
# Feature counts:
# {np.int64(0): array([0, 1, 0, 2]), np.int64(1): array([2, 0, 2, 1])}
