# %%
import numpy as np
import tensorflow as tf

# %%
npz_train = np.load(r'Audiobooks_data_train.npz')
train_inputs, train_targets = npz_train['inputs'].astype(np.float64), npz_train['targets'].astype(np.int64)

npz_validation = np.load(r'Audiobooks_data_validation.npz')
validation_inputs, validation_targets = npz_validation['inputs'].astype(np.float64), npz_validation['targets'].astype(np.int64)

npz_test = np.load(r'Audiobooks_data_test.npz')
test_inputs, test_targets = npz_test['inputs'].astype(np.float64), npz_test['targets'].astype(np.int64)

# %%
input_size = 10
output_size = 2
hidden_layer_size = 50

model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])
d
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

batch_size = 100
max_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)

model.fit(train_inputs,
         train_targets,
         batch_size = batch_size,
         epochs = max_epochs,
         callbacks = [early_stopping],
         validation_data = (validation_inputs, validation_targets),
         verbose = 2)
# Out:
# Epoch 1/100
# 36/36 - 1s - 24ms/step - accuracy: 0.7038 - loss: 0.5679 - val_accuracy: 0.7562 - val_loss: 0.4893
# Epoch 2/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7762 - loss: 0.4503 - val_accuracy: 0.7964 - val_loss: 0.4110
# Epoch 3/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7932 - loss: 0.4033 - val_accuracy: 0.8009 - val_loss: 0.3756
# Epoch 4/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7899 - loss: 0.3818 - val_accuracy: 0.8233 - val_loss: 0.3531
# Epoch 5/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7991 - loss: 0.3677 - val_accuracy: 0.8188 - val_loss: 0.3445
# Epoch 6/100
# 36/36 - 0s - 3ms/step - accuracy: 0.8047 - loss: 0.3582 - val_accuracy: 0.8322 - val_loss: 0.3316
# Epoch 7/100
# 36/36 - 0s - 4ms/step - accuracy: 0.8108 - loss: 0.3523 - val_accuracy: 0.8345 - val_loss: 0.3261
# Epoch 8/100
# 36/36 - 0s - 3ms/step - accuracy: 0.8055 - loss: 0.3504 - val_accuracy: 0.8412 - val_loss: 0.3225
# Epoch 9/100
# ...

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7934 - loss: 0.3528

# %%
print("Test loss {0:.2f}. Test Accuracy {1:.2f}%" .format(test_loss, test_accuracy*100.))
# Out:
# Test loss 0.35. Test Accuracy 78.79%
